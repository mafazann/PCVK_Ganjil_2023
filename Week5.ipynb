# %% [markdown]
# <a href="https://colab.research.google.com/github/mafazann/PCVK_Ganjil_2023/blob/main/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # M. RIZKY MAFAZAN (16)
# # 2141720140
# # TI - 3F

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## TUGAS PRAKTIKUM

# %% [markdown]
# 1. **Buat Gamma Correction sesuai dengan petunjuk berikut**
#
# Percobaan ini akan meminta anda membuat Gamma Correction. Pada percobaan ini, nilai
# Gamma akan diset dengan meminta masukan dari pengguna. Berikut adalah kode untuk
# meminta masukan nilai dari pengguna. Lanjutkan kode tersebut dengan membuat image
# dengan gamma correction sesuai rumus yang telah diberikan.

# %%
print(' Gamma Correction pada citra ')
print('----------------------------------')
try:
 gamma = int(input('Masukkan nilai Gamma: '))
except ValueError:
 print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff')
gamma_image = np.zeros(original.shape, original.dtype)

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      gamma_image[y,x,c] = np.clip(255 * pow  (original[y,x,c] / 255, (1 / gamma)), 0, 255)

final_frame = cv.hconcat((original, gamma_image))
cv2_imshow(final_frame)
# Out:
#  Gamma Correction pada citra
# ----------------------------------
# Masukkan nilai Gamma: 3
# <PIL.Image.Image image mode=RGB size=512x256>

# %% [markdown]
# 2. **Buat Simulasi Image Depth**
#
# Percobaan ini digunakan sebagai simulasi dari proses kuantisasi citra. Pada kuantisasi citra,
# pixel dapat direpresentasikan dengan n-bit kedalaman (default menggunakan 8-bit). Pada
# pixel 8-bit, warna yang memungkinkan adalah 256 warna, dari 0 (0000 0000) hingga
# 255(1111 1111). Pada pixel 7-bit, warna yang memungkinkan adalah 128 warna, dari 0 (000
# 0000) hingga 127 (111 1111). Kemungkinan warna didapat dari pangkat 2 jumlah bit. Jika
# 7bit, maka jumlah warnanya adalah 27 = 128, dst.

# %%
bit_depth=2
level = 255 / (pow(2,bit_depth)-1)
original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff', cv.IMREAD_GRAYSCALE)
depth_image = np.zeros(original.shape, original.dtype)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/female.tiff', cv.IMREAD_GRAYSCALE)
depth_image = np.zeros(original.shape, original.dtype)

bit_depth=2

level = 255/(2**bit_depth)-1

for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    depth_image[y,x] = np.clip(round(original[y,x]/level) * level, 0, 255)

# Menampilkan gambar
plt.figure(figsize=(8, 6))

# Menggabungkan gambar asli dan depth_image
combined_image = np.concatenate((original, depth_image), axis=1)

# Menampilkan gambar gabungan
plt.imshow(combined_image, cmap='gray', vmin=0, vmax=255)
plt.axis('on')

plt.show()

# %% [markdown]
# 3. **Buat modul Average Denoising**
#
# Buat modul average denoising sesuai dengan rumus yang telah diberikan pada sub bab
# sebelumnya.
# Citra asli sudah disediakan pada /images/galaxy.jpg.
# 100 Citra dengan Gaussian Noise sudah disediakan pada /images/noises/*.jpg

# %%
# 1. Jumlah Citra di Average = 5

import glob
from math import log10, sqrt

original = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/galaxy.jpg')
cv_img = []
for img in glob.glob('/content/drive/MyDrive/PCVK_MM/Images/noises/*.jpg'):
    n = cv.imread(img)
    cv_img.append(n)

dst = cv_img[0]
noise_number = 4
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.536673702387784 (dB)
# <PIL.Image.Image image mode=RGB size=620x256>

# %%
# 2. Jumlah Citra di Average = 10

dst = cv_img[0]
noise_number = 9
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.568633918798227 (dB)
# <PIL.Image.Image image mode=RGB size=620x256>

# %%
# 3. Jumlah Citra di Average = 20

dst = cv_img[0]
noise_number = 19
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.569985020483266 (dB)
# <PIL.Image.Image image mode=RGB size=620x256>

# %%
# 4. Jumlah Citra di Average = 40

dst = cv_img[0]
noise_number = 39
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.527962610768114 (dB)
# <PIL.Image.Image image mode=RGB size=620x256>

# %%
# 5. Jumlah Citra di Average = 80

dst = cv_img[0]
noise_number = 79
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.540242488751716 (dB)
# <PIL.Image.Image image mode=RGB size=620x256>

# %%
# 6. Jumlah Citra di Average = 100

dst = cv_img[0]
noise_number = 99
for i in range(noise_number):
    if i == 0:
        pass
    else:
        alpha = 1.0 / (i + 1)
        beta = 1.0 - alpha
        dst = cv.addWeighted(cv_img[i], alpha, dst, beta, 0.0)

def PSNR(original, compressed):
    mse = np.mean((original - compressed) ** 2)
    if(mse == 0):
      return 100
    max_pixel = 255.0
    psnr = 20 * log10(max_pixel / sqrt(mse))
    return psnr

compressed = dst
psnr = PSNR(original, compressed)

print('Nilai PSNR adalah',psnr,'(dB)')
galaxy_frame = cv.hconcat((original, dst))
cv2_imshow(galaxy_frame)
# Out:
# Nilai PSNR adalah 27.542229406978095 (dB)
# <PIL.Image.Image image mode=RGB size=620x256>

# %% [markdown]
# Kesimpulan : Semakin banyak citra yang di-averaging, semakin baik kualitas citra hasilnya dan semakin rendah tingkat noise-nya. Oleh karena itu, pada percobaan average dengan 100 citra, citra hasil averaging memiliki kualitas yang lebih tinggi dibandingkan dengan percobaan pertama dengan hanya 5 citra.

# %% [markdown]
# 4. Buat image masking untuk image berikut. Image kiri adalah image asli (images/couple.tiff),
# sedangkan image paling kanan adalah hasilnya:

# %%
import cv2
import numpy as np

# Load Original image
couple_image = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)

# Gambar lingkaran mask pertama
mask = cv2.circle(mask, (70, 50), 50, (255,255,255), thickness=-1)

# Gambar lingkaran mask kedua
mask1 = cv2.circle(mask, (190, 50), 50, (255,255,255), thickness=-1)

# Menggunakan bitwise 'AND' operator untuk ngeoverlay lingkaran pada gambar aslinya
result_image = couple_image & mask

# Membuat background result_image menjadi putih
result_image[np.where((result_image == [0,0,0]).all(axis=2))] = [255,255,255]

# Tampilkan
couple_frame = cv.hconcat([couple_image, mask, result_image])
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>

# %% [markdown]
# 5. Lakukan percobaan menggunakan operator lain dan tunjukkan hasilnya pada modul ini.
# Tuliskan hasil analisa anda kenapa citra keluarannya seperti itu.

# %%
# 1. NOT (komplemen)

import cv2
import numpy as np

# Load the original image
couple_image = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)

# Gambar lingkaran mask yang pertama
mask = cv2.circle(mask, (70, 50), 50, (255,255,255), thickness=-1)

# Gambar lingkaran mask yang kedua
mask1 = cv2.circle(mask, (190, 50), 50, (255,255,255), thickness=-1)

# menggunakan bitwise 'NOT' operator untuk ngeoverlay lingkaran pada gambar aslinya
result_image = ~couple_image & ~mask

# Tampilkan
couple_frame = cv.hconcat([couple_image, mask, result_image])
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>

# %%
# 2. OR (Atau)

import cv2
import numpy as np

# Load original image
couple_image = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)

# Gambar lingkaran mask yang pertama
mask = cv2.circle(mask, (70, 50), 50, (255,255,255), thickness=-1)

# Gambar lingkaran mask yang kedua
mask1 = cv2.circle(mask, (190, 50), 50, (255,255,255), thickness=-1)

# Menggunakan bitwise 'AND' operator untuk ngeoverlay lingkaran pada gambar aslinya
result_image = couple_image | mask

# Tampilkan
couple_frame = cv.hconcat([couple_image, mask, result_image])
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>

# %%
# 3. AND (Dan)

import cv2
import numpy as np

# Load original image
couple_image = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)

# Gambar lingkaran mask yang pertama
mask = cv2.circle(mask, (70, 50), 50, (255,255,255), thickness=-1)

# Gambar lingkaran mask yang kedua
mask1 = cv2.circle(mask, (190, 50), 50, (255,255,255), thickness=-1)

# Menggunakan bitwise 'AND' operator untuk ngeoverlay lingkaran pada gambar aslinya
result_image = couple_image & mask

# Tampilkan
couple_frame = cv.hconcat([couple_image, mask, result_image])
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>

# %%
# 4. NAND (Not And)

import cv2
import numpy as np

# Load original image
couple_image = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)

# Gambar lingkaran mask yang pertama
mask = cv2.circle(mask, (70, 50), 50, (255,255,255), thickness=-1)

# Gambar lingkaran mask yang kedua
mask1 = cv2.circle(mask, (190, 50), 50, (255,255,255), thickness=-1)

# Menggunakan bitwise 'AND' operator untuk ngeoverlay lingkaran pada gambar aslinya
result_image = ~couple_image & mask

# Tampilkan
couple_frame = cv.hconcat([couple_image, mask, result_image])
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>

# %%
# 5. XOR (Exclusive Or)

import cv2
import numpy as np

# Load original image
couple_image = cv2.imread('/content/drive/MyDrive/PCVK_MM/Images/couple.tiff')

mask = np.zeros(couple_image.shape, dtype=np.uint8)

# Gambar lingkaran mask yang pertama
mask = cv2.circle(mask, (70, 50), 50, (255,255,255), thickness=-1)

# Gambar lingkaran mask yang kedua
mask1 = cv2.circle(mask, (190, 50), 50, (255,255,255), thickness=-1)

# Menggunakan bitwise 'AND' operator untuk ngeoverlay lingkaran pada gambar aslinya
result_image = couple_image ^ mask

# Tampilkan
couple_frame = cv.hconcat([couple_image, mask, result_image])
cv2_imshow(couple_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=768x256>

# %% [markdown]
# Analisa :
#
# 1. NOT (Komplemen):
#
# Pada operasi ini, Membuat dua lingkaran mask pada citra yang diinisialisasi sebagai nol (hitam) dan kemudian menggunakan operator NOT (~) untuk menghasilkan hasil akhir. Hasilnya adalah citra yang menggambarkan komplemen dari citra asli dan masker lingkaran yang diberikan.Ini berarti semua piksel yang sebelumnya berwarna hitam di citra asli menjadi putih, dan sebaliknya.
# 2. OR (Atau):
#
# Pada operasi ini, Membuat dua lingkaran mask pada citra yang diinisialisasi sebagai nol dan kemudian menggunakan operator OR (|) untuk menggabungkan citra asli dan masker lingkaran. Hasilnya adalah citra yang merupakan hasil dari operasi OR antara citra asli dan masker lingkaran. Ini berarti piksel yang ada di salah satu dari kedua citra akan menjadi putih dalam hasil akhir.
#
# 3. AND (Dan):
#
# Pada operasi ini, Menggunakan operator AND (&) untuk menggabungkan citra asli dan masker lingkaran. Hasilnya adalah citra yang hanya memiliki piksel yang berada pada kedua citra asli dan masker lingkaran. Ini berarti piksel akan menjadi putih hanya jika mereka berada di kedua citra.
#
# 4. NAND (Not And):
#
# Pada operasi ini, Menggunakan operator AND (&) dan NOT (~) untuk menggabungkan citra asli dan masker lingkaran. Hasilnya adalah citra yang merupakan komplemen dari hasil operasi AND antara citra asli dan masker lingkaran. Ini berarti piksel akan menjadi putih jika mereka tidak berada di kedua citra.
#
# 5. XOR (Exclusive Or):
#
# Pada operasi ini, Menggunakan operator XOR (^) untuk menggabungkan citra asli dan masker lingkaran. Hasilnya adalah citra yang hanya memiliki piksel yang ada di salah satu dari kedua citra, tetapi tidak di kedua-duanya. Ini menghasilkan efek perbedaan antara citra asli dan masker lingkaran. Hasil dari setiap operasi bitwise akan bergantung pada hubungan antara piksel-piksel dalam citra asli dan masker lingkaran yang digunakan. Setiap operasi memiliki efek yang berbeda pada citra hasilnya. Anda dapat memilih operasi bitwise yang sesuai dengan kebutuhan Anda untuk memanipulasi citra sesuai dengan tujuan Anda.
